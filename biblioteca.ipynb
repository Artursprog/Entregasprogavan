# %% [markdown]
# <a href="https://colab.research.google.com/github/Artursprog/Entregasprogavan/blob/main/biblioteca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Material:
    def __init__(self, id_material, titulo, categoria):
        self.id_material = id_material
        self.titulo = titulo
        self.categoria = categoria

# %%
class Libro(Material):
    def __init__(self, id_material, titulo, categoria, autor, genero, estado):
        super().__init__(id_material, titulo, categoria)
        self.autor = autor
        self.genero = genero
        self.estado = estado  # 0: Disponible, 1: Prestado

    def registrar(self):
        estado_libro = "Disponible" if self.estado == 0 else "Prestado"
        print(f" Libro registrado - ID: {self.id_material} - {self.titulo} | Autor: {self.autor} | Género: {self.genero} | Estado: {estado_libro}")

# %%
class Revista(Material):
    def __init__(self, id_material, titulo, categoria, edicion, periodicidad, estado):
        super().__init__(id_material, titulo, categoria)
        self.edicion = edicion
        self.periodicidad = periodicidad
        self.estado = estado

    def registrar(self):
        estado_revista = "Disponible" if self.estado == 0 else "Prestado"
        print(f"📰 Revista registrada - ID: {self.id_material} - {self.titulo} | Edición: {self.edicion} | Periodicidad: {self.periodicidad} | Estado: {estado_revista}")

# %%
class MaterialDigital(Material):
    def __init__(self, id_material, titulo, categoria, formato, enlace):
        super().__init__(id_material, titulo, categoria)
        self.formato = formato
        self.enlace = enlace

    def registrar(self):
        print(f" Material Digital registrado - ID: {self.id_material} - {self.titulo} | Formato: {self.formato} | Enlace: {self.enlace}")

# %% [markdown]
# CLASES DE PERSONAS(PERSONAL,USUARIOS)

# %%
class Persona:
    def __init__(self, nombre, correo):
        self.nombre = nombre
        self.correo = correo

class Bibliotecario(Persona):
    def __init__(self, nombre, correo, id_trabajador, sucursal):
        super().__init__(nombre, correo)
        self.id_trabajador = id_trabajador
        self.sucursal = sucursal

    def agregar_material(self,catalogo,libro,revista,m_digital,opc):
        self.catalago=catalogo
        self.libro=libro
        self.revista=revista
        self.m_digital=m_digital
        self.opc=opc

        if self.catalago.id != self.sucursal.No_sucursal:
            print(f"el Bibliotecario:{self.nombre}  en la sucursal:{self.sucursal.No_sucursal}")
            print("No puede agregar un material a un catalogo diferente de su sucursal")
        else:
            print(f"el Bibliotecario:{self.nombre}  en la sucursal:{self.sucursal.No_sucursal}")
            print(f"agrego un nuevo material al catalogo:{self.sucursal.No_sucursal}")
            self.catalago.agregar_catalogo_suc(libro,revista,m_digital,opc)

    def confirmar_prestamo(self,prestamo):
        self.prestamo=prestamo

        if self.prestamo.usuario.historial <= 0:
            print(f"usuario {self.prestamo.usuario.nombre} no pudo recivir el material su historial no se lo permite")
        else:
            if self.prestamo.opc == 0:
                print(f"prestamo autorizado  - usuario {self.prestamo.usuario.nombre} material:{self.prestamo.libro.titulo} fecha de prestamo:{self.prestamo.fecha_prestamo} fecha de entrega:{self.prestamo.fecha_devolucion}")
                self.prestamo.libro.estado = 1;
                self.prestamo.usuario.prestamos.append(self.prestamo.libro)
            if self.prestamo.opc == 1:
                print(f"prestamo autorizado  - usuario {self.prestamo.usuario.nombre} material:{self.prestamo.revista.titulo} fecha de prestamo:{self.prestamo.fecha_prestamo} fecha de entrega:{self.prestamo.fecha_devolucion}")
                self.prestamo.revista.estado = 1;
                self.prestamo.usuario.prestamos.append(self.prestamo.revista)
            if self.prestamo.opc == 2:
                print(f"prestamo autorizado  - usuario {self.prestamo.usuario.nombre} material:{self.prestamo.m_digital.titulo} ")
                self.prestamo.m_digital.estado = 1;
                self.prestamo.usuario.prestamos.append(self.prestamo.m_digital)

class Usuario(Persona):
    def __init__(self, nombre, correo, id_usuario, historial):
        super().__init__(nombre, correo)
        self.id_usuario = id_usuario
        self.historial = historial

        self.prestamos = []

    def ver_catalogo(self, catalogo):
        print(f" {self.nombre} (ID: {self.id_usuario}) está viendo el catálogo de la sucursal {catalogo.id_sucursal}.")
        catalogo.mostrar_materiales()

    def solicitar_prestamo(self, material, bibliotecario):
        if self.historial <= 0:
            print(f" {self.nombre} no puede solicitar préstamos debido a su historial.")
        else:
            print(f" {self.nombre} ha solicitado el préstamo de {material.titulo}.")
            self.prestamos.append(material)
            material.estado = 1  # Marcar como prestado

    def mostrar_prestamos(self,nc):
        opc=nc
        print(f" {self.nombre} tiene los siguientes materiales prestados:")
        for material in self.prestamos:
            print(f"- {material.titulo} ({'Libro' if isinstance(material, Libro) else 'Revista' if isinstance(material, Revista) else 'Material Digital'})")

    def devolver_material(self, material, penalizacion):
        if material in self.prestamos:
            retraso = penalizacion.verificar_fecha()
            if retraso:
                print(f" {self.nombre} ha devuelto {material.titulo} tarde. Se reduce su historial.")
                self.historial -= 1
            else:
                print(f" {self.nombre} ha devuelto {material.titulo} a tiempo. Se mejora su historial.")
                self.historial += 1
            self.prestamos.remove(material)
            material.estado = 0  # Marcar como disponible
        else:
            print(f" {self.nombre} no tiene prestado {material.titulo}.")

# %%
class Catalogo:
    def __init__(self, id_sucursal):
        self.id_sucursal = id_sucursal
        self.materiales = []

    def agregar_material(self, material):
        self.materiales.append(material)

    def mostrar_materiales(self):
        print(f" Catálogo de la Sucursal {self.id_sucursal}")
        for material in self.materiales:
            if isinstance(material, Libro):
                material.registrar()
            elif isinstance(material, Revista):
                material.registrar()
            elif isinstance(material, MaterialDigital):
                material.registrar()

class Prestamo:
    def __init__(self, usuario, material, fecha_prestamo, fecha_devolucion):
        self.usuario = usuario
        self.material = material
        self.fecha_prestamo = fecha_prestamo
        self.fecha_devolucion = fecha_devolucion

    def registrar_prestamo(self):
        print(f" Préstamo registrado - Usuario: {self.usuario.nombre} - Material: {self.material.titulo} - Fecha de préstamo: {self.fecha_prestamo} - Fecha de devolución: {self.fecha_devolucion}")
        self.material.estado = 1  # Marcar como prestado

# %%
class sucursal:

    def __init__(self,No_sucursal,ciudad,catalogo):
        self.No_sucursal=No_sucursal
        self.ciudad=ciudad
        self.catalogo=catalogo


    def mostar_catalago_suc(self):
        opc=self.catalogo.id
        print(f"Sucursal:{self.No_sucursal} con cede en {self.ciudad}")
        self.catalogo.mostrar_cat(opc)

# %%
class prestamo:
    def __init__(self,usuario,libro,revista,m_digital,opc,fecha_prestamo,fecha_devolucion):
        self.fecha_prestamo=fecha_prestamo
        self.fecha_devolucion=fecha_devolucion
        self.usuario=usuario
        self.libro=libro
        self.revista=revista
        self.m_digital=m_digital
        self.opc=opc

    def mostrar_prestamo(self):
        if self.opc==0:
            print(f"prestamo de el material {self.libro.id_material} nombre:{self.libro.nombre}")
        if self.opc==1:
            print(f"prestamo de el material {self.revista.id_material} nombre:{self.revista.nombre}")
        if self.opc==2:
            print(f"prestamo de el material {self.m_digital.id_material} nombre:{self.m_digital.nombre}")

# %%
class penalizacion:
    def __init__(self,prestamo,fecha_dev):
        self.prestamo=prestamo
        self.fecha_dev = fecha_dev
        #self.usuario = usuario
        #datetime.fecha2=fecha_dev

    def verificar_fecha(self,prestamo):
        if prestamo.fecha_devolucion < self.fecha_dev:
            return (1)
        else:
            return(0)
        #print(self.fecha2)

# %%
class catalogo:

    def __init__(self,No_catalago,id):
          self.No_catalago = No_catalago
          self.id=id
          self.lista=[]

    def agregar_catalogo_suc(self,libro,revista,m_digital,opc):
            self.opcion=opc
            self.libro=libro
            self.revista=revista
            self.m_digital=m_digital
            if self.opcion == 0:
                self.lista.append(self.libro)

            if self.opcion == 1:
                self.lista.append(self.revista)

            if self.opcion == 2:
                self.lista.append(self.m_digital)


    def mostrar_cat(self,nc):
        opc=nc
        for libro in self.lista:
            if libro.categoria == 0:
                print(f"id:{libro.id_material} - {libro.titulo} autor:{libro.autor}  genero:{libro.genero}  estado:",end=" ")
                if(libro.estado==0):
                    print("Disponible")
                else:
                    print("Prestado")

        for revista in self.lista:
            if revista.categoria==1:
                print(f"id:{revista.id_material} - {revista.titulo} edicion:{revista.edicion} perdiodo:{revista.periodicidad} estado:",end=" ")
                if(revista.estado==0):print("Disponible")
                else:print("Prestado")

        for m_digital in self.lista:
            if m_digital.categoria==2:
                print(f"id:{m_digital.id_material} - {m_digital.titulo}  categoria:{m_digital.formato}  enlace:{m_digital.enlace}")

    def buscar(self,autor,genero,tp,opc):
        self.autor=autor
        self.genero=genero
        self.tp=tp
        self.opc=opc

        for libro in self.lista:
            if self.opc == 0: #si se quiere buscar por autor
                if(libro.categoria==0 and libro.autor==self.autor): print(f" libro encontrado:{libro.id_material} titulo:{libro.titulo} autor:{libro.autor} genero:{libro.genero}")
            if self.opc == 1: #si se quiere  buscar por genero
                if(libro.categoria==0 and libro.genero==self.genero):print(f" libro encontrado:{libro.id_material} titulo:{libro.titulo} autor:{libro.autor} genero:{libro.genero}")
            if self.opc == 2:#si se quiere bucar por categoria
                if(libro.categoria==0 and libro.categoria==self.tp):print(f" libro encontrado:{libro.id_material} titulo:{libro.titulo} autor:{libro.autor} genero:{libro.genero}")

        for revista in self.lista:
            if self.opc == 2:#si se quiere bucar por categoria
                if(revista.categoria==1 and revista.categoria==self.tp):print(f" Revista encontrada:{revista.id_material} titulo:{revista.titulo} edicion:{revista.edicion}")

        for m_digital in self.lista:
            if self.opc == 2:#si se quiere bucar por categoria
                if(m_digital.categoria==2 and m_digital.categoria==self.tp):print(f" material digital encontrado:{m_digital.id_material} titulo:{m_digital.titulo} enlace:{m_digital.enlace}")

# %%
import datetime

libro0=Libro(" "," "," ",0," ",0)
libro1=Libro("L101","shrek y el burro 8",0,"J.K.Rowling","Fantasia",0)
#libro1.registro_libro()
libro2=Libro("L102","Calculo diferencial",0,"Baldor","Matematicas - Escolar",0)
#libro2.registro_libro()
libro3=Libro("L103","La milla verde",0,"Stephen King","Suspenso - Terror",0)
#libro3.registro_libro()
libro4=Libro("L201","Harry el poter",0,"J.K.Rowling","Fantasia",0)
#libro4.registro_libro()
libro5=Libro("L202","Como programar en C",0,"Harvey M. Deitel","Programacion",0)
#libro5.registro_libro()
libro6=Libro("L203","Shrek y fiona con burro 9",0,"J.K.Rowling","Fantasia",0)
#libro6.registro_libro()
libro7=Libro("L204","Adulterio",0,"Paulo Cohelo","Novela",0)
#libro7.registro_libro()
libro8=Libro("L301","IT",0,"Stephen King","Suspenso - Terror",0)
#libro8.registro_libro()
libro9=Libro("L302","Algebra de Baldor",0,"Baldor","Matematicas - Escolar",0)
#libro9.registro_libro()

revista0=Revista(" "," ",1," "," ",0)
revista1=Revista("R101","Tv Notas",1,"5","enero-febrero",0)
#revista1.registro_revista()
revista2=Revista("R102","Proceso",1,"15","marzo-abril",0)
#revista2.registro_revista()
revista3=Revista("R201","Andar en bicicleta",1,"30","julio",0)
#revista3.registro_revista()
revista4=Revista("R202","Tv Notas",1,"10","agosto-septiembre",0)
#revista4.registro_revista()
revista5=Revista("R301","TIME",1,"40","enero",0)
#revista5.registro_revista()
revista6=Revista("R302","A A A",1,"8","mayo-junio",0)
#revista6.registro_revista()
revista7=Revista("R303","Azteca Deportes",1,"20","agosto",0)
#revista8=Revista("R103","TIME",1,"4","marzo",0)

digital0=MaterialDigital(" "," ",2," "," ")
digital1=MaterialDigital("MD101","Algebra - ejercicios resueltos",2,"PDF","WWW.BUAP/REP/Algebra/Ejercicios_Resueltos")
#digital1.registro_m_digital()
digital2=MaterialDigital("MD102","Curso de programacion avanzada",2,"Video","WWW.Youtube/curso_progra/list")
#digital2.registro_m_digital()
digital3=MaterialDigital("MD201","Repositorio: Derecho",2,"Pagina WEB","WWW.abogadosclara.com")
#digital3.registro_m_digital()
digital4=MaterialDigital("MD202","RCP para principiantes",2,"pdf","WWW.edu.salud/Rcp")
#digital4.registro_m_digital()
digital5=MaterialDigital("MD301","Juegos para aprender",2,"Pagina WEB","WWW.BUAP/juegos/aprender.html")
#digital5.registro_m_digital()
digital6=MaterialDigital("MD302","Guia de inscripcion BUAP",2,"VIDEO","WWW.BUAP/guia/video.mp4")
#digital6.registro_m_digital()


catalogo1=catalogo("cat_01",1)
catalogo1.agregar_catalogo_suc(libro1,revista0,digital0,0)
catalogo1.agregar_catalogo_suc(libro2,revista0,digital0,0)
catalogo1.agregar_catalogo_suc(libro3,revista0,digital0,0)
catalogo1.agregar_catalogo_suc(libro0,revista1,digital0,1)
catalogo1.agregar_catalogo_suc(libro0,revista2,digital0,1)
catalogo1.agregar_catalogo_suc(libro0,revista0,digital1,2)
catalogo1.agregar_catalogo_suc(libro0,revista0,digital2,2)

catalogo2=catalogo("cat_02",2)
catalogo2.agregar_catalogo_suc(libro4,revista0,digital0,0)
catalogo2.agregar_catalogo_suc(libro5,revista0,digital0,0)
catalogo2.agregar_catalogo_suc(libro6,revista0,digital0,0)
catalogo2.agregar_catalogo_suc(libro7,revista0,digital0,0)
catalogo2.agregar_catalogo_suc(libro0,revista3,digital0,1)
catalogo2.agregar_catalogo_suc(libro0,revista4,digital0,1)
catalogo2.agregar_catalogo_suc(libro0,revista0,digital3,2)
catalogo2.agregar_catalogo_suc(libro0,revista0,digital4,2)

catalogo3=catalogo("cat_03",3)
catalogo3.agregar_catalogo_suc(libro8,revista0,digital0,0)
catalogo3.agregar_catalogo_suc(libro9,revista0,digital0,0)
catalogo3.agregar_catalogo_suc(libro0,revista5,digital0,1)
catalogo3.agregar_catalogo_suc(libro0,revista6,digital0,1)
catalogo3.agregar_catalogo_suc(libro0,revista7,digital0,1)
catalogo3.agregar_catalogo_suc(libro0,revista0,digital5,2)
catalogo3.agregar_catalogo_suc(libro0,revista0,digital6,2)


sucursal1=sucursal(1,"Puebla.Pue",catalogo1)
sucursal2=sucursal(2,"Guadalajara.Jal",catalogo2)
sucursal3=sucursal(3,"Michoacan.Mor",catalogo3)

'''#mostar los 3 catalogos{
sucursal1.mostar_catalago_suc()
print(" ")
sucursal2.mostar_catalago_suc()
print(" ")
sucursal3.mostar_catalago_suc()
'''#}
print(" ")
usuario1=Usuario("armando","rios_1307@gmail.com","Rios13",5)
#usuario1.ver_usuario()
usuario2=Usuario("Jose de Jesus","jesus_j@hotmail.com","JdJ25",3)
#usuario2.ver_usuario()
usuario3=Usuario("Maria de Lourdes","lulu_06_95@hotmail.com","Lulu06",0)
#usuario3.ver_usuario()
''''#los usuarios pueden ver los diferentes catalogos
print(" ")
usuario1.ver_catalogo(catalogo3)
print(" ")
usuario2.ver_catalogo(catalogo1)
print(" ")
'''#}

libro10=Libro("LN002","libro_nuevo",0,"Armando Rios","Ejemplo",0)
bibliotecario1=Bibliotecario("Antonio Perez","Perez_Ant@hotmail.com","AP_Suc2",sucursal2)


print(" ")
bibliotecario1.agregar_material(catalogo2,libro10,revista0,digital0,0)


catalogo2.mostrar_cat(0)
print(" ")

fecha1 = datetime.date(2025,4,30) # suponemos que todos los prestamos se realizaron el las mismas fechas
fecha2 = datetime.date(2025,5,10) #fecah de regresar el material FR
fecha3 = datetime.date(2025,5,15) #FR

prestamo1=prestamo(usuario1,libro3,revista1,digital1,0,fecha1,fecha2)
prestamo2=prestamo(usuario1,libro4,revista5,digital1,1,fecha1,fecha3)

fecha4=datetime.date(2025,5,2)
fecha5=datetime.date(2025,6,10)

prestamo3=prestamo(usuario2,libro1,revista1,digital1,0,fecha1,fecha3)
prestamo4=prestamo(usuario2,libro3,revista5,digital1,2,fecha1,fecha4)


prestamo5=prestamo(usuario3,libro7,revista5,digital4,0,fecha1,fecha4)

bibliotecario1.confirmar_prestamo(prestamo1)
bibliotecario1.confirmar_prestamo(prestamo2)
print(" ")
bibliotecario1.confirmar_prestamo(prestamo3)
bibliotecario1.confirmar_prestamo(prestamo4)
print("")
bibliotecario1.confirmar_prestamo(prestamo5)
print(" ")
usuario1.mostrar_prestamos(0)
print(" ")
usuario2.mostrar_prestamos(0)
print(" ")

fecha_1=datetime.date(2025,5,7)
fecha_2=datetime.date(2025,6,1)
pen1=penalizacion(prestamo1,fecha_1)
pen2=penalizacion(prestamo3,fecha_2)
#pen1.verificar_fecha(prestamo1)
usuario1.devolver_material(pen1,prestamo1)
print(" ")
usuario2.devolver_material(pen2,prestamo2)
print(" ")
catalogo1.buscar("J.K.Rowling","Suspenso - Terror",1,2)
catalogo2.buscar("J.K.Rowling","Suspenso - Terror",1,2)
catalogo3.buscar("J.K.Rowling","Suspenso - Terror",1,2)
print(" ")
# Out:
#
#
# el Bibliotecario:Antonio Perez  en la sucursal:2
# agrego un nuevo material al catalogo:2
# id:L201 - Harry el poter autor:J.K.Rowling  genero:Fantasia  estado: Disponible
# id:L202 - Como programar en C autor:Harvey M. Deitel  genero:Programacion  estado: Disponible
# id:L203 - Shrek y fiona con burro 9 autor:J.K.Rowling  genero:Fantasia  estado: Disponible
# id:L204 - Adulterio autor:Paulo Cohelo  genero:Novela  estado: Disponible
# id:LN002 - libro_nuevo autor:Armando Rios  genero:Ejemplo  estado: Disponible
# id:R201 - Andar en bicicleta edicion:30 perdiodo:julio estado: Disponible
# id:R202 - Tv Notas edicion:10 perdiodo:agosto-septiembre estado: Disponible
# id:MD201 - Repositorio: Derecho  categoria:Pagina WEB  enlace:WWW.abogadosclara.com
# id:MD202 - RCP para principiantes  categoria:pdf  enlace:WWW.edu.salud/Rcp
#
# prestamo autorizado  - usuario armando material:La milla verde fecha de prestamo:2025-04-30 fecha de entrega:2025-05-10
# ...
